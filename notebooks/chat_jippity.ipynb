# %%
import pandas as pd

# %%
csv = pd.read_csv("/home/clay/research/kaggle/kaggle_llm/data/kaggle-llm-science-exam/train.csv", index_col=0)
csv.head()
# Out:
#                                                prompt  \
# id
# 0   Which of the following statements accurately d...
# 1   Which of the following is an accurate definiti...
# 2   Which of the following statements accurately d...
# 3   What is the significance of regularization in ...
# 4   Which of the following statements accurately d...
#
#                                                     A  \
# id
# 0   MOND is a theory that reduces the observed mis...
# 1   Dynamic scaling refers to the evolution of sel...
# 2   The triskeles symbol was reconstructed as a fe...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
#
#                                                     B  \
# id
# 0   MOND is a theory that increases the discrepanc...
# 1   Dynamic scaling refers to the non-evolution of...
# 2   The triskeles symbol is a representation of th...
# 3   Regularizing the mass-energy of an electron wi...
# ...

# %%
print(
"""I'm about to give you a list multiple choice question, for each question, read the question carefully and answer to me with 3 letters of the choice you think is the most correct with the most certain one first. For example, I'm expecting your answer to be in a format as shown:

1. ["A", "B", "C"]
2. ["B", "E", "D"]
3. ["C", "B", "A"]
...

which means:
the first question you think A is the most correct, then B and then C respectively
the second question you think B is the most correct, then E and then D respectively
the third question you think C is the most correct, then B and then A respectively

are you ready?""")
# Out:
# I'm about to give you a list multiple choice question, for each question, read the question carefully and answer to me with 3 letters of the choice you think is the most correct with the most certain one first. For example, I'm expecting your answer to be in a format as shown:
#
# 1. ["A", "B", "C"]
# 2. ["B", "E", "D"]
# 3. ["C", "B", "A"]
# ...
#
# which means:
# the first question you think A is the most correct, then B and then C respectively
# the second question you think B is the most correct, then E and then D respectively
# the third question you think C is the most correct, then B and then A respectively
#
# are you ready?

# %%
for i, row in csv.iterrows():
    if i > 20:
        break
    prompt = (
        f"question {i+1}.: {row['prompt']}\n\n"
        + f"choices:\n"
        + f"A: {row['A']}\n"
        + f"B: {row['B']}\n"
        + f"C: {row['C']}\n"
        + f"D: {row['D']}\n"
        + f"E: {row['E']}\n"
    )
    print(prompt)
# Out:
# question 1.: Which of the following statements accurately describes the impact of Modified Newtonian Dynamics (MOND) on the observed "missing baryonic mass" discrepancy in galaxy clusters?
#
# choices:
# A: MOND is a theory that reduces the observed missing baryonic mass in galaxy clusters by postulating the existence of a new form of matter called "fuzzy dark matter."
# B: MOND is a theory that increases the discrepancy between the observed missing baryonic mass in galaxy clusters and the measured velocity dispersions from a factor of around 10 to a factor of about 20.
# C: MOND is a theory that explains the missing baryonic mass in galaxy clusters that was previously considered dark matter by demonstrating that the mass is in the form of neutrinos and axions.
# D: MOND is a theory that reduces the discrepancy between the observed missing baryonic mass in galaxy clusters and the measured velocity dispersions from a factor of around 10 to a factor of about 2.
# ...

# %%
answers = [
    ["E", "B", "D"],
    ["A", "E", "C"],
    ["A", "C", "B"],
    ["A", "D", "C"],
    ["D", "B", "A"],
    ["B", "A", "E"],
    ["D", "A", "C"],
    ["B", "A", "E"],
    ["B", "A", "C"],
    ["A", "B", "C"],
    ["B", "C", "D"],
    ["A", "B", "C"],
    ["C", "E", "A"],
    ["E", "D", "C"],
    ["B", "A", "C"],
    ["B", "D", "A"],
    ["A", "E", "C"],
    ["B", "E", "C"],
    ["B", "A", "E"],
    ["E", "A", "D"],
    ["D", "A", "C"],
]

# %%
soln = csv.iloc[:21, :].copy()
soln["pred0"] = [a[0] for a in answers]
soln["pred1"] = [a[1] for a in answers]
soln["pred2"] = [a[2] for a in answers]
soln.head()
# Out:
#                                                prompt  \
# id
# 0   Which of the following statements accurately d...
# 1   Which of the following is an accurate definiti...
# 2   Which of the following statements accurately d...
# 3   What is the significance of regularization in ...
# 4   Which of the following statements accurately d...
#
#                                                     A  \
# id
# 0   MOND is a theory that reduces the observed mis...
# 1   Dynamic scaling refers to the evolution of sel...
# 2   The triskeles symbol was reconstructed as a fe...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
#
#                                                     B  \
# id
# 0   MOND is a theory that increases the discrepanc...
# 1   Dynamic scaling refers to the non-evolution of...
# 2   The triskeles symbol is a representation of th...
# 3   Regularizing the mass-energy of an electron wi...
# ...

# %%
map3 = 0
ranks_to_scores = [1.0, 1/2, 1/3]


for k in range(3):
    map3 += ranks_to_scores[k] * (soln[f"pred{k}"] == soln[f"answer"]).sum() / len(soln)
print(map3)
# Out:
# 0.6904761904761905

# %%
score = (soln["pred"] == soln["answer"]).mean() * 100
print(score)
# Out:
# 55.00000000000001
