# %%
import pandas as pd

df_1 = pd.read_csv("/home/viktor/Documents/kaggle/kaggle_llm/work_dirs/reproduce-mgoksu-deotte/train_data_1_and_2_final/train_data_final.csv")
df_2 = pd.read_csv("/home/viktor/Documents/kaggle/kaggle_llm/data/cdeotte-60k-data-with-context-v2/all_12_with_context2.csv")

df = pd.concat([df_1, df_2], axis=0, ignore_index=True)

# REPLACE nan with empty string
df = df.fillna("")

df
# Out:
#                                                    prompt
# 0           What is the main focus of GLP1R in the brain?  \
# 1       What is the interpretation of GLP1R being expr...
# 2                          What is the function of GFRα3?
# 3       What is the receptor that GFRα3 forms a signal...
# 4       What is the significance of GFRα3 being upregu...
# ...                                                   ...
# 160470  The outer ear, or ear canal, carries sound to ...
# 160471  What sport involves people quickly finding des...
# 160472       Almost all earthquakes occur at which place?
# 160473  Melting glaciers, rising temperatures and drou...
# 160474  What parts of a human possess the highest conc...
#
#                                                   context
# 0       GLP1R is also expressed in the brain where it ...  \
# 1       Stretch responsive vagal neurons in the stomac...
# 2       GDNF family receptor alpha-3 (GFRα3), also kno...
# 3       GDNF family receptor alpha-3 (GFRα3), also kno...
# 4       In mouse models of osteoarthritis, GFRα3 was u...
# ...                                                   ...
# 160470  The ear canal (external acoustic meatus, exter...
# 160471  Orienteering sports in which route choice is a...
# 160472  This subduction zone led to the formation of t...
# 160473  Impacts include changes in regional rainfall p...
# 160474  In thermoregulation, body heat is generated mo...
#
#                                                         A
# 0       To regulate blood sugar level by increasing gl...  \
# 1                    It controls appetite and weight gain
# 2                               To bind to artemin ligand
# 3                                                    GFRα
# 4       It prevents artemin from binding and signaling...
# ...                                                   ...
# 160470                                              aorta
# 160471                                            mapping
# 160472                                          mountains
# 160473                             nature's natural cycle
# 160474
#
#                                                         B
# 0           To control appetite and stimulate weight gain  \
# 1               It enhances insulin synthesis and release
# 2       To form a signaling receptor complex with RET ...
# 3                      Glycosylphosphatidylinositol (GPI)
# 4       It forms a signaling receptor complex with RET...
# ...                                                   ...
# 160470                                           ear lobe
# 160471
# 160472                                    land boundaries
# 160473                                      air pollution
# 160474                                      hand and ears
#
#                                                         C
# 0                To enhance insulin synthesis and release  \
# 1             It regulates glucagon synthesis and release
# 2       To prevent artemin from binding and signaling ...
# 3                            RET tyrosine kinase receptor
# 4                          It binds to the artemin ligand
# ...                                                   ...
# 160470                                            eardrum
# 160471                                       orienteering
# 160472                                   plate boundaries
# 160473                                     global warming
# 160474                                      face and hair
#
#                                                         D
# 0                          To improve memory and learning  \
# 1       It communicates with additional organ systems ...
# 2                         To upregulate in sensory nerves
# 3                                          Artemin ligand
# 4       It allows mice to use their limbs again two ho...
# ...                                                   ...
# 160470                                              lungs
# 160471                                         patterning
# 160472                                  continental shelf
# 160473                                     sudden warming
# 160474                                      face and ears
#
#                                                         E answer source
# 0                To inhibit insulin synthesis and release      D
# 1                         It improves memory and learning      D
# 2       To use their limbs again two hours post-treatment      A
# 3                                   Monoclonal antibodies      C
# 4       It is a glycosylphosphatidylinositol(GPI)-link...      A
# ...                                                   ...    ...    ...
# 160470                                                         C   12.0
# 160471                                           sticking      C   12.0
# 160472                                                         C   12.0
# 160473                                                         C   12.0
# 160474                                     hands and feet      D   12.0
#
# [160475 rows x 9 columns]

# %%
df_valid = pd.read_csv("/home/viktor/Documents/kaggle/kaggle_llm/work_dirs/reproduce-mgoksu-deotte/test_data/train_context_0.csv")[:16]
df_valid
# Out:
#                                                prompt
# 0   Which of the following statements accurately d...  \
# 1   Which of the following is an accurate definiti...
# 2   Which of the following statements accurately d...
# 3   What is the significance of regularization in ...
# 4   Which of the following statements accurately d...
# 5   Which of the following statements accurately d...
# 6   Which of the following statements accurately d...
# 7   Which of the following statements accurately d...
# 8   What is the term used in astrophysics to descr...
# 9      What is the role of axioms in a formal theory?
# 10  What did Fresnel predict and verify with regar...
# 11  What is the relationship between the Wigner fu...
# 12  What is one of the examples of the models prop...
# 13                           What is the Roche limit?
# 14  What is Martin Heidegger's view on the relatio...
# 15             What is the "ultraviolet catastrophe"?
#
#                                               context
# 0   The presence of a clustered thick disk-like co...  \
# 1   Many of these systems evolve in a self-similar...
# 2   It is possible that this usage is related with...
# 3   Renormalization is distinct from regularizatio...
# 4   Several qualitative observations can be made o...
# 5   For a closed Gaussian surface, electric flux i...
# 6   This extra-block can be treated as a (-1)-dime...
# 7   The temperature at or above which an antiferro...
# 8   While such phenomena are sometimes referred to...
# 9   A formal system is an abstract structure used ...
# 10  For added confidence, Fresnel predicted and ve...
# 11  Under the Wigner map, the density matrix trans...
# 12  The current standard model of cosmology is the...
# 13  In celestial mechanics, the Roche limit, also ...
# 14  ===Time=== Heidegger believes that time finds ...
# 15  The ultraviolet catastrophe, also called the R...
#
#                                                     A
# 0   MOND is a theory that reduces the observed mis...  \
# 1   Dynamic scaling refers to the evolution of sel...
# 2   The triskeles symbol was reconstructed as a fe...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
# 5   Gauss's law holds only for situations involvin...
# 6   The dimension of an object in a CW complex is ...
# 7   The blocking temperature of an antiferromagnet...
# 8                                        Blueshifting
# 9   Basis statements called axioms form the founda...
# 10  Fresnel predicted and verified that three tota...
# 11  The Wigner function W(x, p) is the Wigner tran...
# 12  The Copernican principle, which proposes that ...
# 13  The Roche limit is the distance at which tidal...
# 14  Martin Heidegger believes that humans exist wi...
# 15  It is a phenomenon that occurs only in multi-m...
#
#                                                     B
# 0   MOND is a theory that increases the discrepanc...  \
# 1   Dynamic scaling refers to the non-evolution of...
# 2   The triskeles symbol is a representation of th...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
# 5   Gauss's law holds in all cases, but it is most...
# 6   The dimension of an object in a CW complex is ...
# 7   The blocking temperature of an antiferromagnet...
# 8                                         Redshifting
# 9   Axioms are supplementary statements added to a...
# 10  Fresnel predicted and verified that eight tota...
# 11  The Wigner function W(x, p) is a source functi...
# 12  Inhomogeneous cosmology, which states that the...
# 13  The Roche limit is the distance at which tidal...
# 14  Martin Heidegger believes that humans do not e...
# 15  It is the misbehavior of a formula for higher ...
#
#                                                     C
# 0   MOND is a theory that explains the missing bar...  \
# 1   Dynamic scaling refers to the evolution of sel...
# 2   The triskeles symbol is a representation of a ...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
# 5   Gauss's law, which applies equally to all elec...
# 6   The dimension of an object in a CW complex is ...
# 7   The blocking temperature of an antiferromagnet...
# 8                                           Reddening
# 9   Axioms are redundant statements that can be de...
# 10  Fresnel predicted and verified that four total...
# 11  The Wigner function W(x, p) is the derivative ...
# 12  Inhomogeneous cosmology, which models the univ...
# 13  The Roche limit is the distance at which tidal...
# 14  Martin Heidegger does not believe in the exist...
# 15  It is the standing wave of a string in harmoni...
#
#                                                     D
# 0   MOND is a theory that reduces the discrepancy ...  \
# 1   Dynamic scaling refers to the non-evolution of...
# 2   The triskeles symbol represents three interloc...
# 3   Regularizing the mass-energy of an electron wi...
# 4   The angular spacing of features in the diffrac...
# 5   Gauss's law only holds for electric fields wit...
# 6   The dimension of an object in a CW complex is ...
# 7   The blocking temperature of an antiferromagnet...
# 8                                           Whitening
# 9   The axioms in a theory are used for experiment...
# 10  Fresnel predicted and verified that two total ...
# 11  The Wigner function W(x, p) represents the Ham...
# 12  The cosmological principle, which proposes tha...
# 13  The Roche limit is the distance at which tidal...
# 14  Martin Heidegger believes that the relationshi...
# 15  It is a flaw in classical physics that results...
#
#                                                     E answer
# 0   MOND is a theory that eliminates the observed ...      D
# 1   Dynamic scaling refers to the evolution of sel...      A
# 2   The triskeles symbol is a representation of th...      A
# 3   Regularizing the mass-energy of an electron wi...      C
# 4   The angular spacing of features in the diffrac...      D
# 5   Gauss's law, which holds for all situations, i...      B
# 6   The dimension of an object in a CW complex dep...      A
# 7   The blocking temperature of an antiferromagnet...      D
# 8                                           Yellowing      C
# 9   The axioms in a formal theory are added to pro...      A
# 10  Fresnel predicted and verified that four total...      E
# 11  The Wigner function W(x, p) is the time deriva...      A
# 12  The principle of dark energy, which proposes t...      C
# 13  The Roche limit is the distance at which tidal...      D
# 14  Martin Heidegger believes that time is an illu...      B
# 15  It is a disproven theory about the distributio...      B

# %%
df['context_len'] = df['context'].apply(lambda x: len(x))

import matplotlib.pyplot as plt

plt.hist(df['context_len'], bins=100, range=(0, 16000));

# %%
from transformers import LongformerTokenizer, LongformerForMultipleChoice

tokenizer = LongformerTokenizer.from_pretrained("/home/viktor/Documents/kaggle/kaggle_llm/data/kaggle-datasets/longformer-race-model/longformer_qa_model")
model = LongformerForMultipleChoice.from_pretrained("/home/viktor/Documents/kaggle/kaggle_llm/data/kaggle-datasets/longformer-race-model/longformer_qa_model").cuda()
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.9
# CUDA SETUP: Detected CUDA version 121
# CUDA SETUP: Loading binary /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda121.so...
# /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /home/viktor/miniconda3/envs/torch-env did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('vs/workbench/api/node/extensionHostProcess')}
#   warn(msg)
# /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//matplotlib_inline.backend_inline')}
#   warn(msg)

# %%
import torch 
torch.cuda.empty_cache()

# %%
def prepare_answering_input(
        tokenizer, 
        question,  
        options,   
        context,   
        max_seq_length=2048,
    ):
    c_plus_q   = context + ' ' + tokenizer.bos_token + ' ' + question
    c_plus_q_4 = [c_plus_q] * len(options)
    tokenized_examples = tokenizer(
        c_plus_q_4, options,
        max_length=max_seq_length,
        padding="longest",
        truncation=False,
        return_tensors="pt",
    )
    input_ids = tokenized_examples['input_ids'].unsqueeze(0)
    attention_mask = tokenized_examples['attention_mask'].unsqueeze(0)
    example_encoded = {
        "input_ids": input_ids.to(model.device.index),
        "attention_mask": attention_mask.to(model.device.index),
    }
    return example_encoded

# %%
import numpy as np
import torch
from tqdm import tqdm

contexts = []
predictions = []
submit_ids = []

loss_fct = torch.nn.CrossEntropyLoss()
grad_accum = 128
optimizer = torch.optim.Adam(model.parameters(), lr=5e-6 )

indices = np.arange(df.shape[0])
loss_train = 0

n_epochs = 1000

for epoch in range(n_epochs):
    for index in tqdm(indices, total=len(indices)):
        row = df.iloc[index]
        # question is 'prompt'
        question = row['prompt']
        options = [row['A'], row['B'], row['C'], row['D'], row['E']]
        context = row['context']
        answer = row['answer']

        answer_onehot = np.zeros(5)
        answer_onehot[ord(answer) - ord('A')] = 1

        inputs = prepare_answering_input(
            tokenizer=tokenizer, question=question,
            options=options, context=context[:1024],
        )

        logits = model(**inputs).logits
        probability = torch.softmax(logits, dim=-1)

        # apply categorical cross entropy loss
        answer_index = torch.argmax(torch.tensor(answer_onehot)).cuda().long()
        answer_index = answer_index.unsqueeze(0)
        loss = loss_fct(logits, answer_index)

        # backward pass
        loss.backward()
        
        loss_train += loss.item()

        # update each grad_accum steps
        if index % grad_accum == 0 and index > 0:
            optimizer.step()
            optimizer.zero_grad()
            print(f"index={index}. loss {loss_train / grad_accum}")
            loss_train = 0
            
            model.eval()
            torch.cuda.empty_cache()
            # evaluate 
            indices_val = np.arange(df_valid.shape[0])
            map3 = 0
            for index_val in tqdm(indices_val, total=len(indices_val)):
                row = df_valid.iloc[index_val]
                # question is 'prompt'
                question = row['prompt']
                options = [row['A'], row['B'], row['C'], row['D'], row['E']]
                context = row['context']
                answer = row['answer']
                answer_index = ord(answer) - ord('A')
                
                inputs = prepare_answering_input(
                    tokenizer=tokenizer, question=question,
                    options=options, context=context[:4096],
                )
                with torch.no_grad():
                    logits = model(**inputs).logits
                    probability = torch.softmax(logits, dim=-1)
                    # get indices of top 3 predictions
                    top3 = torch.topk(probability, 3, dim=-1).indices.squeeze(0).tolist()
                    
                    # if best answer is answer_index, then map3 += 1
                    # if second best answer is answer_index, then map3 += 1/2
                    # if third best answer is answer_index, then map3 += 1/3
                    for i, ans in enumerate(top3):
                        if ans == answer_index:
                            map3 += 1 / (i + 1)
                
            map3 /= df_valid.shape[0]
            
            print(f"map3={map3}")
            
            model.train()
# Out:
#   0%|          | 0/160475 [00:00<?, ?it/s]
#   0%|          | 128/160475 [01:17<26:37:45,  1.67it/s]
# index=128. loss 1.219559833279618
# 100%|██████████| 16/16 [00:05<00:00,  3.13it/s]
#   0%|          | 129/160475 [01:23<98:49:16,  2.22s/it]
# map3=0.71875
#   0%|          | 256/160475 [02:41<27:06:17,  1.64it/s]
# index=256. loss 1.039076647188267
# 100%|██████████| 16/16 [00:04<00:00,  3.20it/s]
#   0%|          | 257/160475 [02:46<98:31:08,  2.21s/it]
# map3=0.75
#   0%|          | 263/160475 [02:51<28:59:01,  1.54it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:44                                                                                   │
# │                                                                                                  │
# │   41 │   │   loss = loss_fct(logits, answer_index)                                               │
# │   42 │   │                                                                                       │
# │   43 │   │   # backward pass                                                                     │
# │ ❱ 44 │   │   loss.backward()                                                                     │
# │   45 │   │                                                                                       │
# │   46 │   │   loss_train += loss.item()                                                           │
# │   47                                                                                             │
# │                                                                                                  │
# │ /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/torch/_tensor.py:487 in       │
# │ backward                                                                                         │
# │                                                                                                  │
# │    484 │   │   │   │   create_graph=create_graph,                                                │
# │    485 │   │   │   │   inputs=inputs,                                                            │
# │    486 │   │   │   )                                                                             │
# │ ❱  487 │   │   torch.autograd.backward(                                                          │
# │    488 │   │   │   self, gradient, retain_graph, create_graph, inputs=inputs                     │
# │    489 │   │   )                                                                                 │
# │    490                                                                                           │
# │                                                                                                  │
# │ /home/viktor/miniconda3/envs/torch-env/lib/python3.9/site-packages/torch/autograd/__init__.py:20 │
# │ 0 in backward                                                                                    │
# │                                                                                                  │
# │   197 │   # The reason we repeat same the comment below is that                                  │
# │   198 │   # some Python versions print out the first line of a multi-line function               │
# │   199 │   # calls in the traceback and some print out the last line                              │
# │ ❱ 200 │   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the bac   │
# │   201 │   │   tensors, grad_tensors_, retain_graph, create_graph, inputs,                        │
# │   202 │   │   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to ru   │
# │   203                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
