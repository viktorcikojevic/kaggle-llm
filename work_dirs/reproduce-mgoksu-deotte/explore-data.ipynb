# %%
import pandas as pd

path = "/home/viktor/Documents/kaggle/kaggle_llm/work_dirs/reproduce-mgoksu-deotte/train_data/train_context_0.csv"
df = pd.read_csv(path)

# remove rows where answer is not either A, B, C, D or E
df = df[df['answer'].isin(['A', 'B', 'C', 'D', 'E'])]

df.to_csv(path, index=False)

df['answer'].value_counts()
# Out:
# answer
# A    348
# B    212
# C    208
# D    131
# E     90
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("/home/viktor/Documents/kaggle/kaggle_llm/work_dirs/reproduce-mgoksu-deotte/train_data_final/train_data_final.csv")

df['context_len'] = df['context'].apply(lambda x: len(x))

import matplotlib.pyplot as plt
# Out:
# (0.0, 1000.0)

# %%
plt.hist(df['context_len'], bins=100, range=(0, 10000));
# Out:
# (array([0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 5.000e+00, 8.000e+00, 9.000e+00, 2.500e+01, 2.000e+01,
#         4.100e+01, 7.700e+01, 9.900e+01, 1.770e+02, 2.450e+02, 3.660e+02,
#         5.470e+02, 7.400e+02, 9.580e+02, 1.336e+03, 1.664e+03, 2.025e+03,
#         2.405e+03, 2.867e+03, 3.185e+03, 3.546e+03, 3.799e+03, 3.919e+03,
#         4.153e+03, 4.265e+03, 4.201e+03, 4.191e+03, 3.997e+03, 3.957e+03,
#         3.640e+03, 3.576e+03, 3.220e+03, 3.173e+03, 2.839e+03, 2.516e+03,
#         2.355e+03, 2.128e+03, 1.877e+03, 1.746e+03, 1.565e+03, 1.413e+03,
#         1.316e+03, 1.065e+03, 9.970e+02, 8.470e+02, 7.880e+02, 6.510e+02,
#         6.020e+02, 5.620e+02, 4.850e+02, 3.860e+02, 3.700e+02, 3.200e+02,
#         2.810e+02, 2.400e+02, 2.360e+02, 1.990e+02, 1.630e+02, 1.860e+02,
#         1.450e+02, 1.290e+02, 1.110e+02, 1.140e+02, 9.400e+01, 1.000e+02,
#         7.700e+01, 6.800e+01, 6.400e+01, 6.500e+01, 5.600e+01, 5.400e+01,
#         5.500e+01, 3.900e+01, 4.000e+01, 3.700e+01, 3.500e+01, 2.800e+01,
#         2.300e+01, 3.000e+01, 2.000e+01, 1.600e+01, 2.900e+01, 2.100e+01,
#         2.800e+01, 1.500e+01, 2.700e+01, 2.700e+01]),
#  array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#           800.,   900.,  1000.,  1100.,  1200.,  1300.,  1400.,  1500.,
#          1600.,  1700.,  1800.,  1900.,  2000.,  2100.,  2200.,  2300.,
#          2400.,  2500.,  2600.,  2700.,  2800.,  2900.,  3000.,  3100.,
#          3200.,  3300.,  3400.,  3500.,  3600.,  3700.,  3800.,  3900.,
#          4000.,  4100.,  4200.,  4300.,  4400.,  4500.,  4600.,  4700.,
#          4800.,  4900.,  5000.,  5100.,  5200.,  5300.,  5400.,  5500.,
#          5600.,  5700.,  5800.,  5900.,  6000.,  6100.,  6200.,  6300.,
#          6400.,  6500.,  6600.,  6700.,  6800.,  6900.,  7000.,  7100.,
#          7200.,  7300.,  7400.,  7500.,  7600.,  7700.,  7800.,  7900.,
#          8000.,  8100.,  8200.,  8300.,  8400.,  8500.,  8600.,  8700.,
#          8800.,  8900.,  9000.,  9100.,  9200.,  9300.,  9400.,  9500.,
#          9600.,  9700.,  9800.,  9900., 10000.]),
#  <BarContainer object of 100 artists>)
